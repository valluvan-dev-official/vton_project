# %% [markdown]
# # 02 — Preprocessing Test
#
# Test the preprocessing pipeline on a single image pair.

# %%
import sys
sys.path.insert(0, '..')

from src.data.preprocess import preprocess_pair
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Replace with actual paths
PERSON_PATH = '../data/raw/person/sample.jpg'
GARMENT_PATH = '../data/raw/garment/sample.jpg'

result = preprocess_pair(PERSON_PATH, GARMENT_PATH, '/tmp/vton_test_out')
print('Outputs:', result)

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
for ax, (title, path) in zip(axes, result.items()):
    ax.imshow(Image.open(path))
    ax.set_title(title)
    ax.axis('off')
plt.tight_layout()
plt.show()
